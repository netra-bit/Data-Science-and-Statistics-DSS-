# %%
#Experiment_no : 5

# %%
#Aim: Creation of arrays

# %%
#Name: Shruti Giri
#Roll no: 17
#Sec: C
#Subject: ET 1

# %%
import numpy as np

# %%
#creating 1D array
a1=np.array([10,20,30,40])

# %%
a1
# Out:
# array([10, 20, 30, 40])

# %%
#creating 2D array
a2=np.array([[20,44,32,64],[22,14,71,26]])

# %%
a2
# Out:
# array([[20, 44, 32, 64],
#        [22, 14, 71, 26]])

# %%
#creating 2D array using matrix
a3=np.matrix('11,,36;45,21;64,49')

# %%
a3
# Out:
# matrix([[11, 36],
#         [45, 21],
#         [64, 49]])

# %%
#creating an array of 20 random integers
arr = np.random.randint(1,101,size=20)
print(arr)
# Out:
# [20 75 11 92 53 98 94  9 38 94 47 67 48 88 77 85 35 25 96 13]
