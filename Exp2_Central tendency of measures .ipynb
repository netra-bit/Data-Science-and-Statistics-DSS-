# %%
#Exp no: 2

# %%
#Aim : Central tendencies of measures Mean,Median,Mode

# %%
#Name: Shruti Giri
#Roll no: 17
#Sec: C
#Subject: ET 1
#Date: 01-08-25

# %%
age=[20,21,20,22,21,21,20,21,22,22,20,21,20]

# %%
age
# Out:
# [20, 21, 20, 22, 21, 21, 20, 21, 22, 22, 20, 21, 20]

# %%
print(age)
# Out:
# [20, 21, 20, 22, 21, 21, 20, 21, 22, 22, 20, 21, 20]

# %%
import statistics

# %%
a= statistics.mean(age)

# %%
a
# Out:
# 20.846153846153847

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 20

# %%
import numpy as np 
x=np.array([1,2,3,2,4,3,1,3,4,4,2,1,3])

# %%
x
# Out:
# array([1, 2, 3, 2, 4, 3, 1, 3, 4, 4, 2, 1, 3])

# %%
print(np.mean(x))
# Out:
# 2.5384615384615383

# %%
print(np.median(x))
# Out:
# 3.0

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=array([3]), count=array([4]))

# %%
print(np.std(x))
# Out:
# 1.08240363688233

# %%
print(np.var(x))
# Out:
# 1.1715976331360947
