# %%
#Experiment_no: 7

# %%
#Name: Shruti Giri
#Roll no: 17
#Sec: C
#Subject: ET 1

# %%
#Aim:Simple linear Regression

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\giris'

# %%
os.chdir('C:\\Users\\giris\\OneDrive\\Desktop')

# %%
data=pd.read_csv("salary.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
data.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.isna()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
x=data.drop('Salary',axis=1)

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y=data.Salary

# %%
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Line chart

# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)
plt.title("line chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_trian,y_test=train_test_split(x,y,test_size=.3,random_state=50)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.30)

# %%
print(x_train.shape)
# Out:
# (21, 1)

# %%
x_test.shape
# Out:
# (9, 1)

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Assigning coefficient (slope) to m 
m=LR.coef_

# %%
print("Coefficient:",m)
# Out:
# Coefficient: [9360.26128619]

# %%
c=LR.intercept_

# %%
print("Intercept:",c)
# Out:
# Intercept: 26777.391341197632

# %%
#Shows how much accurate the trained model is.
Accuracy=LR.score(x_test,y_test)
Accuracy
# Out:
# 0.9740993407213511

# %% [markdown]
# # Mean Absolute Error

# %%
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5524/1900466560.py in <module>
# ----> 1 print(metrics.mean_absolute_error(y_test,y_pred))
#
# NameError: name 'metrics' is not defined
